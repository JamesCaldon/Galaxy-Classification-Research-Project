# %%
"""

This is for morphological classification of galaxies by CNN,
New regresssion for B/D ratio
By Kenji Bekki, on 2018/3/30

"""


import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.utils import np_utils
from keras.models import model_from_json
### Added 2018/3/30
from keras.applications import imagenet_utils
from keras.models import load_model
###
import keras.callbacks
import numpy as np
#import keras.backend.tensorflow_backend as KTF
#import tensorflow as tf
import os.path


### Total model number = (100*1) * nmodel

#iset=int(input('Input the total number of sets of models '))
#nmodel0=int(input('Input the total number of images per model '))
#nmodel=nmodel0*iset
#epochs=int(input('Input the number of epochs'))
iset=5
nmodel0=100
epochs=50
nmodel=nmodel0*iset
nmodel=1000
print('nmodel',nmodel)

### Original values
#batch_size = 128
#num_classes = 10
#epochs = 12
batch_size = 200
num_classes = 2
#epochs = 500
nb_epoch=epochs
n_mesh=50
#n_mesh=20
#nmodel=4000

img_rows, img_cols = n_mesh, n_mesh
n_mesh2=n_mesh*n_mesh-1
n_mesh3=n_mesh*n_mesh


print(img_rows, img_cols, n_mesh2)
#stop



#(x_train, y_train), (x_test, y_test) = mnist.load_data()
#x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
#x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)

input_shape = (img_rows, img_cols, 1)

#x_train = x_train.astype('float32')
#x_test = x_test.astype('float32')
#x_train /= 255
#x_test /= 255
#print('x_train shape:', x_train.shape)
#print(x_train.shape[0], 'train samples')
#print(x_test.shape[0], 'test samples')
#print(y_test.shape[0], 'y.test samples')
#print(str(y_test[0]))
#print(str(y_test[1]))
#print(str(y_test[2]))

#y_train = y_train.astype('int32')
#y_test = y_test.astype('int32')
#y_train = keras.utils.np_utils.to_categorical(y_train, num_classes)
#y_test =  keras.utils.np_utils.to_categorical(y_test, num_classes)

# This is for simlation data sets
# Out:
# nmodel 1000
# 50 50 2499

# %%
from sklearn import model_selection

x_dataset_series = np.genfromtxt('2dft.dat', autostrip=True, max_rows=nmodel*n_mesh3)
y_dataset1 = np.genfromtxt('2dftn1.dat', autostrip=True, max_rows=nmodel)
y_dataset2 = np.genfromtxt('2dftn2.dat', autostrip=True, max_rows=nmodel)

x_dataset = x_dataset_series.reshape(nmodel, img_rows, img_cols, 1)
y_dataset = np.c_[y_dataset1, y_dataset2]

print(x_dataset.shape)
print(y_dataset.shape)

#x_train = x_dataset
#x_test = x_dataset

#y_train = y_dataset
#y_test = y_dataset
# Out:
# (1000, 50, 50, 1)
# (1000, 2)

# %%
x_train, x_test, y_train, y_test = model_selection.train_test_split(x_dataset, y_dataset, test_size=0.2)

# %%
print('Galaxy type',y_train[:5])

#stop

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

### For labelling of morphological types

#model.add(Dense(num_classes, activation='softmax'))
#model.compile(loss=keras.losses.categorical_crossentropy,
#              optimizer=keras.optimizers.Adadelta(),
#              metrics=['accuracy'])

### For regression of B/D

model.add(Dense(2, activation='linear'))
#model.add(Dense(1))
#model.add(Activation=('linear'))
#model.add(activation=('linear'))
model.compile(loss='mean_squared_error',
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
          verbose=1, validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])


print('save the architecture of a model')

model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Galaxy type [[2.33194852e+00 2.82155895e+00]
#  [5.29747343e+00 5.95053053e-03]
#  [4.17486000e+00 4.30847740e+00]
#  [1.78327715e+00 8.28354740e+00]
#  [4.86517382e+00 4.88943195e+00]]
# Epoch 1/50
# 4/4 [==============================] - 3s 379ms/step - loss: 33.2194 - accuracy: 0.4855 - val_loss: 32.0569 - val_accuracy: 0.4600
# Epoch 2/50
# 4/4 [==============================] - 0s 44ms/step - loss: 32.4568 - accuracy: 0.4845 - val_loss: 31.9495 - val_accuracy: 0.4600
# Epoch 3/50
# 4/4 [==============================] - 0s 41ms/step - loss: 32.8310 - accuracy: 0.4657 - val_loss: 31.8328 - val_accuracy: 0.4600
# Epoch 4/50
# 4/4 [==============================] - 0s 42ms/step - loss: 32.4619 - accuracy: 0.4975 - val_loss: 31.7135 - val_accuracy: 0.4600
# Epoch 5/50
# 4/4 [==============================] - 0s 40ms/step - loss: 32.3645 - accuracy: 0.4925 - val_loss: 31.5859 - val_accuracy: 0.4600
# Epoch 6/50
# 4/4 [==============================] - 0s 42ms/step - loss: 32.6117 - accuracy: 0.4443 - val_loss: 31.4501 - val_accuracy: 0.4600
# Epoch 7/50
# 4/4 [==============================] - 0s 41ms/step - loss: 32.5971 - accuracy: 0.5092 - val_loss: 31.3049 - val_accuracy: 0.4600
# Epoch 8/50
# 4/4 [==============================] - 0s 44ms/step - loss: 32.6703 - accuracy: 0.5147 - val_loss: 31.1515 - val_accuracy: 0.4600
# Epoch 9/50
# 4/4 [==============================] - 0s 41ms/step - loss: 31.5633 - accuracy: 0.4852 - val_loss: 30.9930 - val_accuracy: 0.4650
# Epoch 10/50
# 4/4 [==============================] - 0s 43ms/step - loss: 31.6746 - accuracy: 0.5197 - val_loss: 30.8232 - val_accuracy: 0.4800
# Epoch 11/50
# 4/4 [==============================] - 0s 42ms/step - loss: 31.8985 - accuracy: 0.5062 - val_loss: 30.6169 - val_accuracy: 0.5400
# Epoch 12/50
# 4/4 [==============================] - 0s 43ms/step - loss: 31.4622 - accuracy: 0.5020 - val_loss: 30.3797 - val_accuracy: 0.5400
# Epoch 13/50
# 4/4 [==============================] - 0s 40ms/step - loss: 30.9252 - accuracy: 0.5207 - val_loss: 30.1223 - val_accuracy: 0.5200
# Epoch 14/50
# 4/4 [==============================] - 0s 39ms/step - loss: 31.2900 - accuracy: 0.4733 - val_loss: 29.8277 - val_accuracy: 0.5050
# Epoch 15/50
# 4/4 [==============================] - 0s 41ms/step - loss: 30.3579 - accuracy: 0.5068 - val_loss: 29.5017 - val_accuracy: 0.4650
# Epoch 16/50
# 4/4 [==============================] - 0s 40ms/step - loss: 29.9349 - accuracy: 0.5092 - val_loss: 29.1628 - val_accuracy: 0.4600
# Epoch 17/50
# 4/4 [==============================] - 0s 43ms/step - loss: 30.5845 - accuracy: 0.4857 - val_loss: 28.8141 - val_accuracy: 0.4600
# Epoch 18/50
# 4/4 [==============================] - 0s 44ms/step - loss: 29.8616 - accuracy: 0.5023 - val_loss: 28.4651 - val_accuracy: 0.4600
# Epoch 19/50
# 4/4 [==============================] - 0s 44ms/step - loss: 29.3360 - accuracy: 0.5072 - val_loss: 28.1080 - val_accuracy: 0.4600
# Epoch 20/50
# 4/4 [==============================] - 0s 45ms/step - loss: 28.6791 - accuracy: 0.5087 - val_loss: 27.7396 - val_accuracy: 0.4600
# Epoch 21/50
# 4/4 [==============================] - 0s 49ms/step - loss: 28.2969 - accuracy: 0.4797 - val_loss: 27.3403 - val_accuracy: 0.4600
# Epoch 22/50
# 4/4 [==============================] - 0s 48ms/step - loss: 28.3150 - accuracy: 0.4793 - val_loss: 26.9286 - val_accuracy: 0.4600
# Epoch 23/50
# 4/4 [==============================] - 0s 47ms/step - loss: 27.2938 - accuracy: 0.4818 - val_loss: 26.4938 - val_accuracy: 0.4600
# Epoch 24/50
# 4/4 [==============================] - 0s 45ms/step - loss: 27.5654 - accuracy: 0.4737 - val_loss: 26.0498 - val_accuracy: 0.4600
# Epoch 25/50
# 4/4 [==============================] - 0s 45ms/step - loss: 26.1752 - accuracy: 0.4778 - val_loss: 25.5991 - val_accuracy: 0.4600
# Epoch 26/50
# 4/4 [==============================] - 0s 44ms/step - loss: 26.1242 - accuracy: 0.5113 - val_loss: 25.1292 - val_accuracy: 0.4600
# Epoch 27/50
# 4/4 [==============================] - 0s 46ms/step - loss: 26.0773 - accuracy: 0.4848 - val_loss: 24.6584 - val_accuracy: 0.4600
# Epoch 28/50
# 4/4 [==============================] - 0s 40ms/step - loss: 25.4802 - accuracy: 0.4527 - val_loss: 24.1704 - val_accuracy: 0.4600
# Epoch 29/50
# 4/4 [==============================] - 0s 39ms/step - loss: 24.6638 - accuracy: 0.4935 - val_loss: 23.6701 - val_accuracy: 0.4600
# Epoch 30/50
# 4/4 [==============================] - 0s 44ms/step - loss: 23.6471 - accuracy: 0.4800 - val_loss: 23.1461 - val_accuracy: 0.4600
# Epoch 31/50
# 4/4 [==============================] - 0s 43ms/step - loss: 23.9736 - accuracy: 0.5045 - val_loss: 22.6103 - val_accuracy: 0.4600
# Epoch 32/50
# 4/4 [==============================] - 0s 43ms/step - loss: 23.4885 - accuracy: 0.5113 - val_loss: 22.0693 - val_accuracy: 0.4600
# Epoch 33/50
# 4/4 [==============================] - 0s 42ms/step - loss: 22.5922 - accuracy: 0.4838 - val_loss: 21.5034 - val_accuracy: 0.4600
# Epoch 34/50
# 4/4 [==============================] - 0s 45ms/step - loss: 21.5081 - accuracy: 0.4950 - val_loss: 20.9251 - val_accuracy: 0.4600
# Epoch 35/50
# 4/4 [==============================] - 0s 43ms/step - loss: 21.1568 - accuracy: 0.5232 - val_loss: 20.3412 - val_accuracy: 0.4600
# Epoch 36/50
# 4/4 [==============================] - 0s 47ms/step - loss: 20.9521 - accuracy: 0.4938 - val_loss: 19.7393 - val_accuracy: 0.4600
# Epoch 37/50
# 4/4 [==============================] - 0s 46ms/step - loss: 19.9960 - accuracy: 0.5130 - val_loss: 19.1271 - val_accuracy: 0.4600
# Epoch 38/50
# 4/4 [==============================] - 0s 45ms/step - loss: 19.3271 - accuracy: 0.5218 - val_loss: 18.5123 - val_accuracy: 0.4600
# Epoch 39/50
# 4/4 [==============================] - 0s 41ms/step - loss: 19.2796 - accuracy: 0.4897 - val_loss: 17.8831 - val_accuracy: 0.4600
# Epoch 40/50
# 4/4 [==============================] - 0s 41ms/step - loss: 18.2883 - accuracy: 0.5207 - val_loss: 17.2529 - val_accuracy: 0.4600
# Epoch 41/50
# 4/4 [==============================] - 0s 45ms/step - loss: 17.6867 - accuracy: 0.4988 - val_loss: 16.6303 - val_accuracy: 0.4600
# Epoch 42/50
# 4/4 [==============================] - 0s 42ms/step - loss: 17.5396 - accuracy: 0.4803 - val_loss: 16.0048 - val_accuracy: 0.4600
# Epoch 43/50
# 4/4 [==============================] - 0s 40ms/step - loss: 16.9362 - accuracy: 0.4872 - val_loss: 15.3877 - val_accuracy: 0.4600
# Epoch 44/50
# 4/4 [==============================] - 0s 38ms/step - loss: 16.2604 - accuracy: 0.4983 - val_loss: 14.7772 - val_accuracy: 0.4600
# Epoch 45/50
# 4/4 [==============================] - 0s 48ms/step - loss: 15.2721 - accuracy: 0.4547 - val_loss: 14.1846 - val_accuracy: 0.4600
# Epoch 46/50
# 4/4 [==============================] - 0s 47ms/step - loss: 14.6598 - accuracy: 0.4913 - val_loss: 13.6056 - val_accuracy: 0.4600
# Epoch 47/50
# 4/4 [==============================] - 0s 45ms/step - loss: 14.4735 - accuracy: 0.4817 - val_loss: 13.0502 - val_accuracy: 0.4600
# Epoch 48/50
# 4/4 [==============================] - 0s 47ms/step - loss: 13.8885 - accuracy: 0.5087 - val_loss: 12.5279 - val_accuracy: 0.4600
# Epoch 49/50
# 4/4 [==============================] - 0s 42ms/step - loss: 13.1672 - accuracy: 0.4935 - val_loss: 12.0270 - val_accuracy: 0.4600
# Epoch 50/50
# 4/4 [==============================] - 0s 40ms/step - loss: 12.5924 - accuracy: 0.5282 - val_loss: 11.5568 - val_accuracy: 0.4600
# Test score: 11.556750297546387
# Test accuracy: 0.46000000834465027
# save the architecture of a model
# Saved model to disk
